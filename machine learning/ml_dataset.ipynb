# %%
from sklearn.linear_model import LinearRegression 
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd

# %%
#Linear Regression 
X = [[1000] ,[2000],[3000],[4000],[5000]]
y  = [10,20,30,40,50]

# %%
#y = mX(bar) + c
#create the object for linear regression 
model = LinearRegression()

# %%
# Out:
# m---> 0.010000000000000002
# c---> -7.105427357601002e-15
# [20.17]

# %%
plt.scatter(X,y)
plt.show()

# %%
#to show the predicited value data 
w = [[1000] ,[2000],[3000],[4000],[5000] , [6000]] 
plt.scatter(X,y)
plt.plot(w,model.predict(w) , color = 'green')
plt.show()

# %%
import pandas as pd

df = pd.read_csv("Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
x= df[["SepalLengthCm","SepalWidthCm","PetalWidthCm"]]
print(x)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalWidthCm
# 0              5.1           3.5           0.2
# 1              4.9           3.0           0.2
# 2              4.7           3.2           0.2
# 3              4.6           3.1           0.2
# 4              5.0           3.6           0.2
# ..             ...           ...           ...
# 145            6.7           3.0           2.3
# 146            6.3           2.5           1.9
# 147            6.5           3.0           2.0
# 148            6.2           3.4           2.3
# 149            5.9           3.0           1.8
#
# [150 rows x 3 columns]

# %%
y = df[["PetalLengthCm"]]
print(y)
# Out:
#      PetalLengthCm
# 0              1.4
# 1              1.4
# 2              1.3
# 3              1.5
# 4              1.4
# ..             ...
# 145            5.2
# 146            5.0
# 147            5.2
# 148            5.4
# 149            5.1
#
# [150 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y , test_size = 0.2 , random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train , y_train)

prediction = model.predict(x_test)
print(prediction)
# Out:
# [[4.12907977]
#  [1.87775771]
#  [7.02910351]
#  [4.43236278]
#  [4.92926532]
#  [2.0639232 ]
#  [3.84942915]
#  [6.12878356]
#  [5.02657149]
#  [3.97602415]
#  [5.33502143]
#  [1.44630795]
#  [1.7788798 ]
#  [1.45452896]
#  [1.44325388]
#  [4.5394617 ]
#  [5.75667844]
#  [3.81294994]
#  [3.98604275]
#  [5.81265373]
#  [1.39213025]
#  [4.8804804 ]
#  [1.77425398]
#  [5.66602153]
#  [5.96368591]
#  [6.04814525]
#  [5.63596573]
#  [5.99216996]
#  [1.73957236]
#  [1.52874386]]

# %%
from sklearn.metrics import(mean_absolute_error, mean_squared_error , r2_score , root_mean_squared_error)

mae = mean_absolute_error(y_test , prediction)
print("mean_abosulte error--->", mae)

mse = mean_squared_error(y_test , prediction)
print("mean_squared_error---->", mse)

R2 = r2_score(y_test , prediction)**0.5
print("R2---->",R2)

root_data = root_mean_squared_error(y_test , prediction)
print("Root_data---->",root_data)
# Out:
# mean_abosulte error---> 0.26061732392888853
# mean_squared_error----> 0.12991981605759934
# R2----> 0.9799789501558266
# Root_data----> 0.36044391527337416

# %%
df = pd.read_csv("penguins.csv")
df
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# 2                195.0       3250.0  female  2007
# 3                  NaN          NaN     NaN  2007
# 4                193.0       3450.0  female  2007
# ..                 ...          ...     ...   ...
# 339              207.0       4000.0    male  2009
# 340              202.0       3400.0  female  2009
# 341              193.0       3775.0    male  2009
# 342              210.0       4100.0    male  2009
# 343              198.0       3775.0  female  2009
#
# [344 rows x 9 columns]

# %%
x= df[["bill_length_mm" , "bill_depth_mm" ,"flipper_length_mm"]]
print(x)
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm
# 0              39.1           18.7              181.0
# 1              39.5           17.4              186.0
# 2              40.3           18.0              195.0
# 3               NaN            NaN                NaN
# 4              36.7           19.3              193.0
# ..              ...            ...                ...
# 339            55.8           19.8              207.0
# 340            43.5           18.1              202.0
# 341            49.6           18.2              193.0
# 342            50.8           19.0              210.0
# 343            50.2           18.7              198.0
#
# [344 rows x 3 columns]

# %%
y = df[["body_mass_g"]]
print(y)
# Out:
#      body_mass_g
# 0         3750.0
# 1         3800.0
# 2         3250.0
# 3            NaN
# 4         3450.0
# ..           ...
# 339       4000.0
# 340       3400.0
# 341       3775.0
# 342       4100.0
# 343       3775.0
#
# [344 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y , test_size = 0.2 , random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
x_train = x_train.fillna(0)
x_test = x_test.fillna(0)

y_train = y_train.fillna(0)
y_test = y_test.fillna(0)

model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
model = LinearRegression()
model.fit(x_train , y_train)

prediction = model.predict(x_test)
print(prediction)
# Out:
# [[4602.12216049]
#  [4606.28146635]
#  [4971.0735607 ]
#  [4497.80410129]
#  [4033.89555856]
#  [4386.34202915]
#  [3967.50974806]
#  [4496.3358846 ]
#  [3744.41558413]
#  [5090.68335382]
#  [3969.45127909]
#  [3798.97735889]
#  [3441.63554976]
#  [4218.45197579]
#  [3939.98544078]
#  [3763.02523816]
#  [4012.64308905]
#  [5190.82858172]
#  [4380.95985082]
#  [3925.6732145 ]
#  [4181.01041556]
#  [3492.87357633]
#  [5681.83354058]
#  [3701.98300906]
#  [5655.41718608]
#  [4629.38759809]
#  [4034.38822643]
#  [4545.61885469]
#  [3872.97279932]
#  [4666.19649928]
#  [3818.66406614]
#  [3934.61293922]
#  [5601.60881812]
#  [3621.8944291 ]
#  [3376.07946883]
#  [3563.45344094]
#  [4270.54282401]
#  [5402.39343614]
#  [3691.83008864]
#  [4503.66927072]
#  [4105.18638438]
#  [4537.98800197]
#  [3864.15954033]
#  [3499.84471913]
#  [4331.79960791]
#  [5283.52165512]
#  [3684.27258109]
#  [3284.11473075]
#  [4944.04379057]
#  [3364.94902017]
#  [4718.66509568]
#  [3889.34147632]
#  [3379.62733845]
#  [3722.05318243]
#  [4606.5229619 ]
#  [3395.43098364]
#  [4859.42211538]
#  [4887.41588831]
#  [5530.93327722]
#  [5002.49445548]
#  [4036.21868645]
#  [4096.89284415]
#  [3665.06303685]
#  [4269.56144709]
#  [5034.9141013 ]
#  [4048.69660403]
#  [3690.39464078]
#  [3908.54915128]]

# %%
model.fit(x_train, y_train)


prediction = model.predict(x_test)
print(prediction)
# Out:
# [[4602.12216049]
#  [4606.28146635]
#  [4971.0735607 ]
#  [4497.80410129]
#  [4033.89555856]
#  [4386.34202915]
#  [3967.50974806]
#  [4496.3358846 ]
#  [3744.41558413]
#  [5090.68335382]
#  [3969.45127909]
#  [3798.97735889]
#  [3441.63554976]
#  [4218.45197579]
#  [3939.98544078]
#  [3763.02523816]
#  [4012.64308905]
#  [5190.82858172]
#  [4380.95985082]
#  [3925.6732145 ]
#  [4181.01041556]
#  [3492.87357633]
#  [5681.83354058]
#  [3701.98300906]
#  [5655.41718608]
#  [4629.38759809]
#  [4034.38822643]
#  [4545.61885469]
#  [3872.97279932]
#  [4666.19649928]
#  [3818.66406614]
#  [3934.61293922]
#  [5601.60881812]
#  [3621.8944291 ]
#  [3376.07946883]
#  [3563.45344094]
#  [4270.54282401]
#  [5402.39343614]
#  [3691.83008864]
#  [4503.66927072]
#  [4105.18638438]
#  [4537.98800197]
#  [3864.15954033]
#  [3499.84471913]
#  [4331.79960791]
#  [5283.52165512]
#  [3684.27258109]
#  [3284.11473075]
#  [4944.04379057]
#  [3364.94902017]
#  [4718.66509568]
#  [3889.34147632]
#  [3379.62733845]
#  [3722.05318243]
#  [4606.5229619 ]
#  [3395.43098364]
#  [4859.42211538]
#  [4887.41588831]
#  [5530.93327722]
#  [5002.49445548]
#  [4036.21868645]
#  [4096.89284415]
#  [3665.06303685]
#  [4269.56144709]
#  [5034.9141013 ]
#  [4048.69660403]
#  [3690.39464078]
#  [3908.54915128]]

# %%
print("y_test:", y_test.shape)
print("prediction:", prediction.shape)

print("y_test length:", len(y_test.squeeze()))
print("prediction length:", len(prediction.ravel()))
# Out:
# y_test: (69, 1)
# prediction: (68, 1)
# y_test length: 69
# prediction length: 68

# %%
x_test = x_test.dropna()

# %%
print("y_test:", y_test.shape)
print("prediction:", prediction.shape)

print("y_test length:", len(y_test.squeeze()))
print("prediction length:", len(prediction.ravel()))
# Out:
# y_test: (68, 1)
# prediction: (68, 1)
# y_test length: 68
# prediction length: 68

# %%
comparision = pd.DataFrame({
    "Actual_value":y_test.squeeze(), 
    "Prediction_value":prediction.ravel()})
comparision
# Out:
#      Actual_value  Prediction_value
# 194        4300.0       4602.122160
# 157        4550.0       4606.281466
# 225        5200.0       4971.073561
# 208        4300.0       4497.804101
# 318        3550.0       4033.895559
# ..            ...               ...
# 45         4600.0       4269.561447
# 321        4450.0       5034.914101
# 172        5700.0       4048.696604
# 73         4150.0       3690.394641
# 76         3700.0       3908.549151
#
# [68 rows x 2 columns]

# %%
from sklearn.metrics import(mean_absolute_error, mean_squared_error , r2_score , root_mean_squared_error)

mae = mean_absolute_error(y_test , prediction)
print("mean_abosulte error--->", mae)

mse = mean_squared_error(y_test , prediction)
print("mean_squared_error---->", mse)

R2 = r2_score(y_test , prediction)**0.5
print("R2---->",R2)

root_data = root_mean_squared_error(y_test , prediction)
print("Root_data---->",root_data)
# Out:
# mean_abosulte error---> 533.8386377303465
# mean_squared_error----> 725587.230963625
# R2----> 0.3599716820189982
# Root_data----> 851.8140823933501
